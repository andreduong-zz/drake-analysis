# %%
import lyricsgenius

# %%
genius = lyricsgenius.Genius("eSR7c1P5KYwQh6MUFFrK7nGQ7q_3dL_BYDm1fui3GDA8X55knqsXekmDXOuN66Fq")
artist = genius.search_artist("Drake", max_songs=1000, sort="title")
# Out:
# Searching for songs by Drake...
#
# Song 1: "."
# Song 2: "0 to 100 / The Catch Up"
# Song 3: "10 Bands"
# Song 4: "1Xtra Freestyle"
# Song 5: "2011 Juno Awards In Toronto"
# Song 6: "2016 MTV VMAs Vanguard Award Intro for Rihanna"
# Song 7: "2AM"
# Song 8: "305 to My City"
# Song 9: "30 for 30 Freestyle"
# Song 10: "4422"
# Song 11: "4PM in Calabasas"
# Song 12: "5AM in Toronto"
# Song 13: "6 God"
# Song 14: "6 Man"
# Song 15: "6PM in New York"
# Song 16: "8AM in London*"
# Song 17: "8 Out of 10"
# Song 18: "9"
# Song 19: "9AM in Dallas"
# Song 20: "About the Game"
# Song 21: "After Dark"
# Song 22: "A Little Bit"
# Song 23: "A Little Favour (GQ Freestyle)"
# Song 24: "All Kinds"
# Song 25: "All Me"
# Song 26: "All Night Long (Miss Me Demo)"
# Song 27: "All This Love"
# Song 28: "Alton Sterling Statement"
# Song 29: "AM 2 PM"
# Song 30: "A Milli Freestyle"
# Song 31: "A Night Off"
# Song 32: "Apology for Autism Line"
# Song 33: "A Scorpio’s Mind"
# Song 34: "Asthma Team"
# ...

# %%
artist.save_lyrics()
# Out:
# Wrote . to lyrics_drake_..json.
# Wrote 0 to 100 / The Catch Up to lyrics_drake_0to100thecatchup.json.
# Wrote 10 Bands to lyrics_drake_10bands.json.
# Wrote 1Xtra Freestyle to lyrics_drake_1xtrafreestyle.json.
# Wrote 2011 Juno Awards In Toronto to lyrics_drake_2011junoawardsintoronto.json.
# Wrote 2016 MTV VMAs Vanguard Award Intro for Rihanna to lyrics_drake_2016mtvvmasvanguardawardintroforrihanna.json.
# Wrote 2AM to lyrics_drake_2am.json.
# Wrote 305 to My City to lyrics_drake_305tomycity.json.
# Wrote 30 for 30 Freestyle to lyrics_drake_30for30freestyle.json.
# Wrote 4422 to lyrics_drake_4422.json.
# Wrote 4PM in Calabasas to lyrics_drake_4pmincalabasas.json.
# Wrote 5AM in Toronto to lyrics_drake_5amintoronto.json.
# Wrote 6 God to lyrics_drake_6god.json.
# Wrote 6 Man to lyrics_drake_6man.json.
# Wrote 6PM in New York to lyrics_drake_6pminnewyork.json.
# Wrote 8AM in London* to lyrics_drake_8aminlondon.json.
# Wrote 8 Out of 10 to lyrics_drake_8outof10.json.
# ...
